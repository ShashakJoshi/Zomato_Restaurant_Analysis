# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:brown;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Zomato Dataset
# </p>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color: darkred;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
#  Domain Knowledge about Zomato
# </p>
# </div>

# %% [markdown]
# <div style="font-family:Georgia;background-color:aliceblue; padding:30px; font-size:17px">
#
# <b>Objective:- Zomato Dataset Exploratory Data analysis.<br>
#
# <b>Description</b><br>
#
# Zomato Restaurant contains the following variables:
#
# 💡 Restaurant Id: Unique id of every restaurant across various cities of the world<br>
# 💡 Restaurant Name: Name of the restaurant<br>
# 💡 Country Code: Country in which restaurant is located<br>
# 💡City: City in which restaurant is located<br>
# 💡Address: Address of the restaurant<br>
# 💡 Locality: Location in the city<br>
# 💡 Longitude: Longitude coordinate of the restaurant's location<br>
# 💡 Latitude: Latitude coordinate of the restaurant's location<br>
# 💡 Cuisines: Cuisines offered by the restaurant<br>
# 💡 Average Cost for two: Cost for two people in different currencies<br>
# 💡 Currency: Currency of the country<br>
# 💡 Has Table booking: yes/no<br>
# 💡 Has Online delivery: yes/ no<br>
# 💡 Is delivering: yes/ nov<br>
# 💡 Switch to order menu: yes/no<br>
# 💡 Price range: range of price of food<br>
# 💡 Aggregate Rating: Average rating out of 5<br>
# 💡 Rating color: depending upon the average rating color<br>
# 💡 Rating text: text on the basis of rating of rating<br>
# 💡 Votes: Number of ratings casted by people<br>
#
# <a id="1.3"></a>
# <h2 style="font-family: Verdana; font-size: 22px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: black; background-color:aliceblue;"><b> Author:- </b> Shashank Joshi</h2>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Importing Libraries
# </p>
# </div>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Loading Datasets
# </p>
# </div>

# %%
df1=pd.read_csv("C:\\Users\\SHAASHANK JOSHI\\Downloads\\zomato.csv")

# %%
df2=pd.read_excel("C:\\Users\\SHAASHANK JOSHI\\Downloads\\Zomato_Country-Code.xlsx")

# %% [markdown]
# ***In df1 we have data of our zomata but in df2 we have the data of those countries which use zomato services with their country code***
#
# ***Further we will merge this 2 datasets***

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Basic Understanding of Data
# </p>
# </div>

# %% [markdown]
# ### Take a look at datasets

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# ### Merging both Datasets for better Analysis

# %%
df=pd.merge(df1,df2,on="Country Code",how="left")

# %% [markdown]
# ***We used merging techinique because Merge combines dataframes based on values in shared Feature***

# %% [markdown]
# ### Take a look at fresh Dataset

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# ###  Checking Dimensions of the Data.

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# ***Our Dataset contain 23 Features (Columns) and 9551 Records(Rows)***

# %% [markdown]
# ###  Checking the Data Type of Features of dataset.

# %%
Dtype=df.dtypes
Dtype.to_frame().rename(columns={0:"Data Type"})
# Out:
#                      Data Type
# Restaurant ID            int64
# Restaurant Name         object
# Country Code             int64
# City                    object
# Address                 object
# Locality                object
# Locality Verbose        object
# Longitude              float64
# Latitude               float64
# Cuisines                object
# Average Cost for two     int64
# Currency                object
# Has Table booking       object
# Has Online delivery     object
# Is delivering now       object
# Switch to order menu    object
# Price range              int64
# Aggregate rating       float64
# Rating color            object
# Rating text             object
# Votes                    int64
# Country                 object

# %% [markdown]
# ### Checking the % missing values in each Features

# %%
(df.isnull().sum()*100/df.shape[0]).to_frame().rename(columns={0:"Missing %"})
# Out:
#                       Missing %
# Restaurant ID          0.000000
# Restaurant Name        0.000000
# Country Code           0.000000
# City                   0.000000
# Address                0.000000
# Locality               0.000000
# Locality Verbose       0.000000
# Longitude              0.000000
# Latitude               0.000000
# Cuisines               0.094231
# Average Cost for two   0.000000
# Currency               0.000000
# Has Table booking      0.000000
# Has Online delivery    0.000000
# Is delivering now      0.000000
# Switch to order menu   0.000000
# Price range            0.000000
# Aggregate rating       0.000000
# Rating color           0.000000
# Rating text            0.000000
# Votes                  0.000000
# Country                0.000000

# %% [markdown]
# ***As you can see above their is no missing values present in any feature except Cuisines***

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:black;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:white;
#           font-size:120%;
#           text-align:center;">
# Exploratory Data Analysis (EDA)
# </p>
# </div>

# %%
country_name = df.Country.value_counts().index
country_val = df.Country.value_counts().values

# %% [markdown]
# ### Top 3 Countries that uses Zomato

# %%
plt.figure(figsize=(10,7))
plt.pie(country_val[:3], labels=country_name[:3],autopct ='%1.2f%%');

# %%
plt.figure(figsize=(8,9))
sns.countplot(x="Country",data=df);
plt.xticks(rotation=(90));

# %% [markdown]
# ***Zomato Maximum Records are from India After that USA and then United Kingdom***

# %% [markdown]
# ### Storing Data of India

# %%
final=df[df["Country"]=="India"]

# %%
plt.figure(figsize=(18,9))
sns.countplot(x="City",data=final)
plt.xticks(rotation=(90));

# %%
k=final["City"].value_counts().reset_index()

# %%
k=k.groupby("index")["City"].sum().reset_index()

# %%
k.iloc[5:,0]="others"

# %%
plt.figure(figsize=(18,9))
plt.pie(x=k["City"],labels=k["index"],autopct="%0.01f%%");
plt.legend()
plt.xticks(rotation=(90));

# %% [markdown]
# ***Zomato Maximum Records are from New Delhi in India***

# %% [markdown]
# ### Country that have given zero rating

# %%
df[df['Rating color']== 'White']
df[df['Rating color']== 'White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# ***As ypu can see above I ndian is the country with most  0 Aggregate Rating***

# %% [markdown]
# ### Which countries do have online deliveries

# %%
df[df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# ***Online deliveries are available in India and UAE***

# %% [markdown]
# ### Avg Rating with respect to rating text

# %%
df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %% [markdown]
# ***When Rating is between 4.5 to 4.9 it means Excellent***\
# ***When Rating is between 4.0 to 4.4 it means Very Good***\
# ***When Rating is between 3.5 to 3.9 it means Good***\
# ***When Rating is between 2.5 to 3.4 it means Average***\
# ***When Rating is between 2.0 to 2.4 it means Poor***

# %%
finaldf.describe().T
# Out:
#                        count          mean           std   min            25%  \
# Restaurant ID         8652.0  8.657085e+06  8.959437e+06  53.0  300740.250000
# Country Code          8652.0  1.000000e+00  0.000000e+00   1.0       1.000000
# Longitude             8652.0  7.285679e+01  1.801754e+01   0.0      77.098797
# Latitude              8652.0  2.642065e+01  6.976576e+00   0.0      28.491425
# Average Cost for two  8652.0  6.233703e+02  5.956761e+02   0.0     300.000000
# Price range           8652.0  1.721683e+00  8.525437e-01   1.0       1.000000
# Aggregate rating      8652.0  2.523324e+00  1.510986e+00   0.0       2.100000
# Votes                 8652.0  1.372126e+02  4.280395e+02   0.0       4.000000
#
#                                50%           75%           max
# Restaurant ID         2.200006e+06  1.836120e+07  1.850065e+07
# Country Code          1.000000e+00  1.000000e+00  1.000000e+00
# Longitude             7.720347e+01  7.728536e+01  9.180649e+01
# ...

# %%
Cuisines=df["Cuisines"].value_counts()

# %%
Cuisines
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# ### which restarant is expensive based on cuisisnes type of reach city

# %%
f=finaldf[finaldf["Average Cost for two"]!=0]
k=f.groupby(["City","Cuisines"])["Average Cost for two"].mean().reset_index().sort_values(by=["City","Average Cost for two"])
k
# Out:
#        City                                           Cuisines  \
# 10     Agra                                         Rajasthani
# 3      Agra                                       North Indian
# 12     Agra                             South Indian, Desserts
# 1      Agra                                     Italian, Pizza
# 8      Agra                            North Indian, Fast Food
# ...     ...                                                ...
# 2203  Vizag  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...
# 2207  Vizag                                            Italian
# 2196  Vizag          American, North Indian, Thai, Continental
# 2210  Vizag               North Indian, Chinese, Mediterranean
# 2204  Vizag                          Continental, North Indian
#
#       Average Cost for two
# 10                   400.0
# 3                    500.0
# 12                   550.0
# 1                    700.0
# 8                    700.0
# ...                    ...
# ...

# %% [markdown]
# how many restarants

# %%
k=f.groupby(["City","Cuisines"])["Aggregate rating"].mean().reset_index().sort_values(by=["City","Aggregate rating"])

# %%
k
# Out:
#        City                                           Cuisines  \
# 5      Agra        North Indian, Chinese, Continental, Mughlai
# 3      Agra                                       North Indian
# 11     Agra                      Rajasthani, Gujarati, Mughlai
# 4      Agra                 North Indian, Chinese, Continental
# 9      Agra                              North Indian, Mughlai
# ...     ...                                                ...
# 2200  Vizag                             Burger, Pizza, Biryani
# 2203  Vizag  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...
# 2207  Vizag                                            Italian
# 2211  Vizag                                   Pizza, Fast Food
# 2210  Vizag               North Indian, Chinese, Mediterranean
#
#       Aggregate rating
# 5                 3.40
# 3                 3.60
# 11                3.60
# 4                 3.80
# 9                 3.84
# ...                ...
# 2200              4.30
# ...

# %%
ratings=finaldf.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:"Rating Count"})

# %%
plt.figure(figsize=(18,9))
sns.barplot(ratings["Aggregate rating"],ratings["Rating Count"]);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(18,9))
sns.barplot(ratings["Aggregate rating"],ratings["Rating Count"],hue="Rating text",data=ratings);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Frequency distribution of rating color in india

# %%
sns.countplot(x="Rating color",data=ratings,palette=["black","red","orange","yellow","green","green"]);

# %%
k=finaldf.groupby(["City","Restaurant Name","Aggregate rating"])["Votes"].mean().reset_index()
k.rename(columns={"mean":"votes"},inplace=True)

# %%
k[k["City"]=="New Delhi"].sort_values(by="Aggregate rating",ascending=False)
# Out:
#            City            Restaurant Name  Aggregate rating   Votes
# 4007  New Delhi  Indian Accent - The Manor               4.9  1934.0
# 4626  New Delhi             Masala Library               4.9   408.0
# 4918  New Delhi         Naturals Ice Cream               4.9  2620.0
# 4333  New Delhi               Kopper Kadai               4.8    83.0
# 4519  New Delhi                MOB Brewpub               4.7    52.0
# ...         ...                        ...               ...     ...
# 3520  New Delhi              Food En Vouge               0.0     0.0
# 3519  New Delhi                 Food Daddy               0.0     1.0
# 6028  New Delhi            Sonu Bhojanalya               0.0     2.0
# 6027  New Delhi            Soni Food Court               0.0     0.0
# 1884  New Delhi               #InstaFreeze               0.0     2.0
#
# [5042 rows x 4 columns]

# %% [markdown]
# ####  How many the not rated Restaurant in each city

# %%
k1=finaldf[finaldf["Aggregate rating"]==0.0]

# %%
k1.groupby("City")["Rating text"].value_counts()
# Out:
# City       Rating text
# Faridabad  Not rated       100
# Ghaziabad  Not rated         2
# Gurgaon    Not rated       228
# New Delhi  Not rated      1425
# Noida      Not rated       384
# Name: Rating text, dtype: int64

# %% [markdown]
# ### Restaurant that offer different type of  delivery prior table booking to thier customers

# %%
print("The number of restaurants which gives online delivery  and proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="Yes")]))
print("The number of restaurants which gives only online delivery  and no proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="No")]))
print("The number of restaurants which gives only proir table booking option and no online delievery----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="Yes")]))
print("The number of restaurants which gives neither option ----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="No")]))
# Out:
# The number of restaurants which gives online delivery  and proir table booking option---- 427
# The number of restaurants which gives only online delivery  and no proir table booking option---- 1996
# The number of restaurants which gives only proir table booking option and no online delievery---- 684
# The number of restaurants which gives neither option ---- 5545
